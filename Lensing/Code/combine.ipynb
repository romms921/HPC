# %%
import pandas as pd
import numpy as np

# %%
data_folder = '/Users/ainsleylewis/Documents/Astronomy/HPC/Lensing/Output/individual_results'

data = pd.DataFrame()

for i in range(50):
    file_path = f'{data_folder}/results_rank_{i}.csv'
    try:
        # Attempt to read the CSV file
        df = pd.read_csv(file_path, header=0)
    except FileNotFoundError:
        # If the file does not exist, skip to the next iteration
        print(f"File {file_path} not found. Skipping.")
        continue
    print("Number of Models in file", i, ":", len(df))
    data = pd.concat([data, df], ignore_index=True)
# Out:
# Number of Models in file 0 : 2000
# Number of Models in file 1 : 2000
# Number of Models in file 2 : 2000
# Number of Models in file 3 : 2000
# Number of Models in file 4 : 2000
# Number of Models in file 5 : 2000
# Number of Models in file 6 : 2000
# Number of Models in file 7 : 2000
# Number of Models in file 8 : 2000
# Number of Models in file 9 : 2000
# Number of Models in file 10 : 2000
# Number of Models in file 11 : 2000
# Number of Models in file 12 : 2000
# Number of Models in file 13 : 2000
# Number of Models in file 14 : 2000
# Number of Models in file 15 : 2000
# Number of Models in file 16 : 2000
# Number of Models in file 17 : 2000
# Number of Models in file 18 : 2000
# Number of Models in file 19 : 2000
# Number of Models in file 20 : 2000
# Number of Models in file 21 : 2000
# Number of Models in file 22 : 2000
# Number of Models in file 23 : 2000
# Number of Models in file 24 : 2000
# Number of Models in file 25 : 2000
# Number of Models in file 26 : 2000
# Number of Models in file 27 : 2000
# Number of Models in file 28 : 2000
# Number of Models in file 29 : 2000
# Number of Models in file 30 : 2000
# Number of Models in file 31 : 2000
# Number of Models in file 32 : 2000
# Number of Models in file 33 : 2000
# Number of Models in file 34 : 2000
# Number of Models in file 35 : 2000
# Number of Models in file 36 : 2000
# Number of Models in file 37 : 2000
# Number of Models in file 38 : 2000
# Number of Models in file 39 : 2000
# Number of Models in file 40 : 2000
# Number of Models in file 41 : 2000
# Number of Models in file 42 : 2000
# Number of Models in file 43 : 2000
# Number of Models in file 44 : 2000
# Number of Models in file 45 : 2000
# Number of Models in file 46 : 2000
# Number of Models in file 47 : 2000
# Number of Models in file 48 : 2000
# Number of Models in file 49 : 2000

# %%
data
# Out:
#           m          n    o  num_images   pos_rms      mag_rms   avg_mag_per  \
# 0      0.01    0.00000  0.0           4  0.000000    15.179374    263.012791
# 1      0.01   18.18182  0.0           4  0.000000    32.680706    460.208057
# 2      0.01   36.36364  0.0           4  0.000000    14.096669    249.405796
# 3      0.01   54.54545  0.0           0       NaN          NaN      0.000000
# 4      0.01   72.72727  0.0           4  0.000000     9.072827    193.648565
# ...     ...        ...  ...         ...       ...          ...           ...
# 99995  0.10  287.27273  0.6           4  0.002418    40.523582    542.878708
# 99996  0.10  305.45455  0.6           4  0.000000    28.594101    411.400740
# 99997  0.10  323.63636  0.6           4  0.000000    36.356770    497.753403
# 99998  0.10  341.81818  0.6           6  0.000000  2252.310860  11449.214471
# 99999  0.10  360.00000  0.6           4  0.000000    20.557368    325.632575
#
#              chi2  source_x  source_y  ...     POW_e  POW_$θ_{e}$  \
# 0        0.000001  0.099060  0.045012  ...  0.110345     4.453713
# 1        0.000002  0.067529  0.034370  ...  0.035425    18.450870
# 2        0.000004  0.050702  0.028995  ...  0.327175     2.435667
# 3      348.408000  0.081626  0.032552  ...  0.000003   -58.972910
# 4        0.000002  0.099619  0.047339  ...  0.127485     4.092227
# ...           ...       ...       ...  ...       ...          ...
# 99995    3.142326  0.091253  0.035083  ...  0.101796    -1.418175
# 99996    0.000003  0.098660  0.041157  ...  0.114102     3.785392
# 99997    0.000002  0.083744  0.040360  ...  0.020108    39.096020
# 99998    0.000003  0.053391  0.084691  ...  0.542922    65.849580
# 99999    0.000003  0.045568  0.026512  ...  0.259172     3.043593
#
#        POW_$r_{Ein}$  POW_$\gamma$ (PWI)  PERT_$z_{s,fid}$  PERT_x  PERT_y  \
# 0           0.525169            1.852308               1.0     0.0     0.0
# 1           0.386467            1.997306               1.0     0.0     0.0
# 2           0.344691            2.172544               1.0     0.0     0.0
# 3           0.428957            2.043481               1.0     0.0     0.0
# 4           0.546226            1.934692               1.0     0.0     0.0
# ...              ...                 ...               ...     ...     ...
# 99995       0.427368            1.692315               1.0     0.0     0.0
# 99996       0.481572            1.721385               1.0     0.0     0.0
# 99997       0.453361            1.850521               1.0     0.0     0.0
# 99998       0.314954            2.138398               1.0     0.0     0.0
# 99999       0.319860            2.199636               1.0     0.0     0.0
#
#        PERT_$\gamma$  PERT_$θ_{\gamma}$  PERT_$\kappa$
# 0       1.447858e-02         -21.488690      -0.082670
# 1       2.919309e-02          -7.668231       0.189873
# 2       9.159025e-03         136.129900       0.323547
# 3       3.103909e-07          78.443390       0.112267
# 4       1.762660e-02         161.079800      -0.131922
# ...              ...                ...            ...
# 99995   1.329805e-07         251.260200       0.075673
# 99996   8.568207e-03         310.969300      -0.003920
# 99997   3.264193e-02         352.279100       0.042975
# 99998   1.344776e-01         328.992000       0.403701
# 99999   1.186689e-02         339.315800       0.384284
#
# [100000 rows x 43 columns]

# %%
data_folder = '/Users/ainsleylewis/Documents/Astronomy/HPC/Lensing/Output/progress_status'

progress = pd.DataFrame()

for i in range(50):
    file_path = f'{data_folder}/worker_{i}.status'
    try:
        df = pd.read_csv(file_path, header=None)
    except FileNotFoundError:
        print(f"File {file_path} not found. Skipping.")
        continue
    progress = pd.concat([progress, df], ignore_index=True)

# %%
progress
# Out:
#        0
# 0   2000
# 1   2000
# 2   2000
# 3   2000
# 4   2000
# 5   2000
# 6   2000
# 7   2000
# 8   2000
# 9   2000
# 10  2000
# 11  2000
# 12  2000
# 13  2000
# 14  2000
# 15  2000
# 16  2000
# 17  2000
# 18  2000
# 19  2000
# 20  2000
# 21  2000
# 22  2000
# 23  2000
# 24  2000
# 25  2000
# 26  2000
# 27  2000
# 28  2000
# 29  2000
# 30  2000
# 31  2000
# 32  2000
# 33  2000
# 34  2000
# 35  2000
# 36  2000
# 37  2000
# 38  2000
# 39  2000
# 40  2000
# 41  2000
# 42  2000
# 43  2000
# 44  2000
# 45  2000
# 46  2000
# 47  2000
# 48  2000
# 49  2000
