# %%
import pandas as pd
import numpy as np

# %%
data_folder = '/Volumes/T7 Shield/Dump/Sim_4/individual_results'

data = pd.DataFrame()

for i in range(100):
    file_path = f'{data_folder}/results_rank_{i}.csv'
    try:
        # Attempt to read the CSV file
        df = pd.read_csv(file_path, header=0)
    except FileNotFoundError:
        # If the file does not exist, skip to the next iteration
        print(f"File {file_path} not found. Skipping.")
        continue
    print("Number of Models in file", i, ":", len(df))
    data = pd.concat([data, df], ignore_index=True)
# Out:
# Number of Models in file 0 : 10000
# Number of Models in file 1 : 10000
# Number of Models in file 2 : 10000
# Number of Models in file 3 : 10000
# Number of Models in file 4 : 10000
# Number of Models in file 5 : 10000
# Number of Models in file 6 : 10000
# Number of Models in file 7 : 10000
# Number of Models in file 8 : 10000
# Number of Models in file 9 : 10000
# Number of Models in file 10 : 10000
# Number of Models in file 11 : 10000
# Number of Models in file 12 : 10000
# Number of Models in file 13 : 10000
# Number of Models in file 14 : 10000
# Number of Models in file 15 : 10000
# Number of Models in file 16 : 10000
# Number of Models in file 17 : 10000
# Number of Models in file 18 : 10000
# Number of Models in file 19 : 10000
# Number of Models in file 20 : 10000
# Number of Models in file 21 : 10000
# Number of Models in file 22 : 10000
# Number of Models in file 23 : 10000
# Number of Models in file 24 : 10000
# Number of Models in file 25 : 10000
# Number of Models in file 26 : 10000
# Number of Models in file 27 : 10000
# Number of Models in file 28 : 10000
# Number of Models in file 29 : 10000
# Number of Models in file 30 : 10000
# Number of Models in file 31 : 10000
# Number of Models in file 32 : 10000
# Number of Models in file 33 : 10000
# Number of Models in file 34 : 10000
# Number of Models in file 35 : 10000
# Number of Models in file 36 : 10000
# Number of Models in file 37 : 10000
# Number of Models in file 38 : 10000
# Number of Models in file 39 : 10000
# Number of Models in file 40 : 10000
# Number of Models in file 41 : 10000
# Number of Models in file 42 : 10000
# Number of Models in file 43 : 10000
# Number of Models in file 44 : 10000
# Number of Models in file 45 : 10000
# Number of Models in file 46 : 10000
# Number of Models in file 47 : 10000
# Number of Models in file 48 : 10000
# Number of Models in file 49 : 10000
# Number of Models in file 50 : 10000
# Number of Models in file 51 : 10000
# Number of Models in file 52 : 10000
# Number of Models in file 53 : 10000
# Number of Models in file 54 : 10000
# Number of Models in file 55 : 10000
# Number of Models in file 56 : 10000
# Number of Models in file 57 : 10000
# Number of Models in file 58 : 10000
# Number of Models in file 59 : 10000
# Number of Models in file 60 : 10000
# Number of Models in file 61 : 10000
# Number of Models in file 62 : 10000
# Number of Models in file 63 : 10000
# Number of Models in file 64 : 10000
# Number of Models in file 65 : 10000
# Number of Models in file 66 : 10000
# Number of Models in file 67 : 10000
# Number of Models in file 68 : 10000
# Number of Models in file 69 : 10000
# Number of Models in file 70 : 10000
# Number of Models in file 71 : 10000
# Number of Models in file 72 : 10000
# Number of Models in file 73 : 10000
# Number of Models in file 74 : 10000
# Number of Models in file 75 : 10000
# Number of Models in file 76 : 10000
# Number of Models in file 77 : 10000
# Number of Models in file 78 : 10000
# Number of Models in file 79 : 10000
# Number of Models in file 80 : 10000
# Number of Models in file 81 : 10000
# Number of Models in file 82 : 10000
# Number of Models in file 83 : 10000
# Number of Models in file 84 : 10000
# Number of Models in file 85 : 10000
# Number of Models in file 86 : 10000
# Number of Models in file 87 : 10000
# Number of Models in file 88 : 10000
# Number of Models in file 89 : 10000
# Number of Models in file 90 : 10000
# Number of Models in file 91 : 10000
# Number of Models in file 92 : 10000
# Number of Models in file 93 : 10000
# Number of Models in file 94 : 10000
# Number of Models in file 95 : 10000
# Number of Models in file 96 : 10000
# Number of Models in file 97 : 10000
# Number of Models in file 98 : 10000
# Number of Models in file 99 : 10000

# %%
data
# Out:
#             m          n    o  num_images   pos_rms       mag_rms  \
# 0       0.001    0.00000  0.0           5  0.008695  5.839198e+02
# 1       0.001   36.03604  0.0           5  0.005985  1.108974e+02
# 2       0.001   72.07207  0.0           0       NaN           NaN
# 3       0.001  108.10811  0.0           1  0.098239  1.078153e+04
# 4       0.001  144.14414  0.0           1  0.036135  4.096353e+05
# ...       ...        ...  ...         ...       ...           ...
# 999995  0.100  215.85586  0.0           1  0.000100  7.504528e+03
# 999996  0.100  251.89189  0.0           1  0.057856  9.697816e+05
# 999997  0.100  287.92793  0.0           3  0.423488  3.563224e+03
# 999998  0.100  323.96396  0.0           5  0.010845  2.184594e+03
# 999999  0.100  360.00000  0.0           1  0.000100  1.122737e+06
#
#          avg_mag_per       chi2  source_x  source_y  ...    ANFW_y  \
# 0       8.080424e+03   200.7213  1.049032  1.099035  ...  1.099456
# 1       1.621614e+03   133.7872  1.047866  1.098172  ...  1.100264
# 2       0.000000e+00   260.1802  1.044522  1.087116  ...  1.087115
# 3       7.978634e+04   629.8741  1.044909  1.087139  ...  1.087543
# 4       3.031416e+06   218.8931  1.044187  1.089067  ...  1.089068
# ...              ...        ...       ...       ...  ...       ...
# 999995  5.553562e+04  1071.7260  1.048480  1.085657  ...  1.085683
# 999996  7.176657e+06   218.3647  1.043963  1.088764  ...  1.088765
# 999997  5.204179e+04  2563.8790  1.069744  1.112790  ...  1.112420
# 999998  3.003578e+04   754.4589  1.051278  1.085571  ...  1.085680
# 999999  8.308570e+06   636.9487  1.050811  1.086188  ...  1.086189
#
#               ANFW_e  ANFW_$θ_{e}$  ANFW_c or $r_{s}$  PERT_$z_{s,fid}$  \
# 0       2.888256e-03      50.24228           69.99263               1.0
# 1       1.007324e-06      44.59994           70.05506               1.0
# 2       2.071075e-07      36.52617           70.02772               1.0
# 3       4.016714e-02      30.07936           70.02673               1.0
# 4       4.858916e-06      51.24690           69.99090               1.0
# ...              ...           ...                ...               ...
# 999995  2.405456e-05      51.35294           70.11464               1.0
# 999996  2.329262e-06      36.48596           70.14516               1.0
# 999997  9.620606e-02      42.53863           69.96118               1.0
# 999998  2.956785e-03      56.66243           70.07902               1.0
# 999999  1.531598e-05      44.12490           70.26248               1.0
#
#         PERT_x  PERT_y  PERT_$\gamma$  PERT_$θ_{\gamma}$  PERT_$\kappa$
# 0         1.06    1.06   2.909867e-04           23.22774            0.0
# 1         1.06    1.06   6.430642e-03           44.91118            0.0
# 2         1.06    1.06   5.299524e-07           70.64164            0.0
# 3         1.06    1.06   1.561710e-02          120.07540            0.0
# 4         1.06    1.06   5.227422e-07          161.30940            0.0
# ...        ...     ...            ...                ...            ...
# 999995    1.06    1.06   6.653090e-05          227.39960            0.0
# 999996    1.06    1.06   3.542883e-07          280.01180            0.0
# 999997    1.06    1.06   3.903415e-02          312.56070            0.0
# 999998    1.06    1.06   8.166147e-04          331.17190            0.0
# 999999    1.06    1.06   5.266278e-06          313.90320            0.0
#
# [1000000 rows x 42 columns]

# %%
data.to_csv('/Volumes/T7 Shield/Simulation Output/System 4/Sim 24.csv', index=False)

# %%
data_folder = '/Volumes/T7 Shield/Dump/Sim_4/progress_status'

progress = pd.DataFrame()

for i in range(100):
    file_path = f'{data_folder}/worker_{i}.status'
    try:
        df = pd.read_csv(file_path, header=None)
    except FileNotFoundError:
        print(f"File {file_path} not found. Skipping.")
        continue
    progress = pd.concat([progress, df], ignore_index=True)

# %%
progress
# Out:
#         0
# 0   10000
# 1   10000
# 2   10000
# 3   10000
# 4   10000
# ..    ...
# 95  10000
# 96  10000
# 97  10000
# 98  10000
# 99  10000
#
# [100 rows x 1 columns]
