# %%
import pandas as pd
import numpy as np

# %%
data_folder = '/Users/ainsleylewis/Documents/Astronomy/HPC/Lensing/Output/individual_results'

data = pd.DataFrame()

for i in range(50):
    file_path = f'{data_folder}/results_rank_{i}.csv'
    df = pd.read_csv(file_path, header=0)
    print("Number of Models in file", i, ":", len(df))
    data = pd.concat([data, df], ignore_index=True)
# Out:
# Number of Models in file 0 : 20
# Number of Models in file 1 : 20
# Number of Models in file 2 : 20
# Number of Models in file 3 : 20
# Number of Models in file 4 : 20
# Number of Models in file 5 : 20
# Number of Models in file 6 : 20
# Number of Models in file 7 : 20
# Number of Models in file 8 : 20
# Number of Models in file 9 : 20
# Number of Models in file 10 : 20
# Number of Models in file 11 : 20
# Number of Models in file 12 : 20
# Number of Models in file 13 : 20
# Number of Models in file 14 : 20
# Number of Models in file 15 : 20
# Number of Models in file 16 : 20
# Number of Models in file 17 : 20
# Number of Models in file 18 : 20
# Number of Models in file 19 : 20
# Number of Models in file 20 : 20
# Number of Models in file 21 : 20
# Number of Models in file 22 : 20
# Number of Models in file 23 : 20
# Number of Models in file 24 : 20
# Number of Models in file 25 : 20
# Number of Models in file 26 : 20
# Number of Models in file 27 : 20
# Number of Models in file 28 : 20
# Number of Models in file 29 : 20
# Number of Models in file 30 : 20
# Number of Models in file 31 : 20
# Number of Models in file 32 : 20
# Number of Models in file 33 : 20
# Number of Models in file 34 : 20
# Number of Models in file 35 : 20
# Number of Models in file 36 : 20
# Number of Models in file 37 : 20
# Number of Models in file 38 : 20
# Number of Models in file 39 : 20
# Number of Models in file 40 : 20
# Number of Models in file 41 : 20
# Number of Models in file 42 : 20
# Number of Models in file 43 : 20
# Number of Models in file 44 : 20
# Number of Models in file 45 : 20
# Number of Models in file 46 : 20
# Number of Models in file 47 : 20
# Number of Models in file 48 : 20
# Number of Models in file 49 : 20

# %%
data
# Out:
#            m    n      o  num_images   pos_rms  \
# 0    1.50000  0.0    0.0           1  0.320659
# 1    1.50000  0.5    0.0           0       NaN
# 2    1.57778  0.0    0.0           0       NaN
# 3    1.57778  0.5    0.0           4  0.002372
# 4    1.65556  0.0    0.0           1  0.305748
# ..       ...  ...    ...         ...       ...
# 995  2.04444  0.9  360.0           4  0.002471
# 996  2.12222  0.4  360.0           5  0.002372
# 997  2.12222  0.9  360.0           4  0.002471
# 998  2.20000  0.4  360.0           4  0.014160
# 999  2.20000  0.9  360.0           4  0.044416
#
#                                                    pos        mag_rms  \
# 0                                         [0.32065871]  384020.922200
# 1                                                   []            NaN
# 2                                                   []            NaN
# 3    [4.47213595e-04 4.70106371e-03 4.47213595e-04 ...      44.671187
# 4                                         [0.30574787]  259879.403200
# ..                                                 ...            ...
# 995  [4.47213595e-04 4.90000000e-03 4.47213595e-04 ...       3.323983
# 996  [4.47213595e-04 4.70106371e-03 4.47213595e-04 ...      78.374199
# 997  [4.47213595e-04 4.90000000e-03 4.47213595e-04 ...       3.475974
# 998      [0.00652763 0.02630779 0.00744648 0.00344819]       3.230684
# 999      [0.02190023 0.06460789 0.02799571 0.04953312]       7.354750
#
#                                        mag  \
# 0                            [384020.9222]
# 1                                       []
# 2                                       []
# 3        [38.7619 11.6029 32.962  72.5152]
# 4                            [259879.4032]
# ..                                     ...
# 995          [2.4616 0.5947 3.0886 5.3144]
# 996  [ 70.5344  19.807   60.7543 124.5454]
# 997          [1.9722 0.7408 2.6602 6.0675]
# 998          [3.6315 0.3215 4.0664 3.4529]
# 999          [9.5696 0.894  9.3055 6.1156]
#
#                                                mag_per   avg_mag_per  \
# 0                                   [3567178.65688278]  3.567179e+06
# 1                                                   []  0.000000e+00
# 2                                                   []  0.000000e+00
# 3    [560.03994055 563.24757282 520.76683534 705.53...  5.873981e+02
# 4                                   [2414090.05387331]  2.414090e+06
# ..                                                 ...           ...
# 995  [177.13542634  28.86893204 169.9435578   51.70...  1.069136e+02
# 996  [ 855.15883336  961.50485437  791.2251849  121...  9.549139e+02
# 997  [181.68121865  35.96116505 174.11249513  59.03...  1.126972e+02
# 998  [166.26880921  15.60679612 160.42818217  33.59...  9.397471e+01
# 999  [111.1127624   43.39805825 109.44433632  59.50...  8.086425e+01
#
#             chi2  source_x  source_y  POW_$z_{s,fid}$     POW_x     POW_y  \
# 0     345.729800  0.091975  0.036653              1.0  0.091977  0.036652
# 1     345.745900  0.091991  0.036722              1.0  0.091994  0.036722
# 2     345.781400  0.092078  0.036675              1.0  0.092078  0.036675
# 3       3.132973  0.100666  0.037955              1.0  0.125459  0.037696
# 4     345.713800  0.092026  0.036695              1.0  0.092030  0.036694
# ..           ...       ...       ...              ...       ...       ...
# 995     3.387430  0.072227  0.038259              1.0  0.155210  0.037263
# 996     3.121418  0.103745  0.037918              1.0  0.122346  0.037725
# 997     3.361990  0.074175  0.038231              1.0  0.153141  0.037296
# 998   276.129600  0.068825  0.028346              1.0  0.164318  0.029393
# 999  6851.977000  0.023025  0.029517              1.0  0.347284  0.034759
#
#             POW_e  POW_$θ_{e}$  POW_$r_{Ein}$  POW_$\gamma$ (PWI)
# 0    1.061013e-05   -24.994590       0.480684            1.500348
# 1    1.579385e-05   -26.150100       0.480705            1.501727
# 2    3.072042e-07   -93.233170       0.480613            1.501747
# 3    8.630757e-02    -1.421508       0.478692            1.628669
# 4    1.636430e-05   -24.341860       0.480661            1.500886
# ..            ...          ...            ...                 ...
# 995  3.537512e-01   358.641200       0.481563            2.196517
# 996  6.250406e-02   358.576000       0.478557            1.512243
# 997  3.340028e-01   358.634900       0.481225            2.174061
# 998  4.000000e-01   360.000000       0.482266            2.200000
# 999  9.350790e-01   360.000000       0.633020            2.200000
#
# [1000 rows x 20 columns]

# %%
data_folder = '/Users/ainsleylewis/Documents/Astronomy/HPC/Lensing/Output/progress_status'

progress = pd.DataFrame()

for i in range(100):
    file_path = f'{data_folder}/worker_{i}.status'
    df = pd.read_csv(file_path, header=None)
    progress = pd.concat([progress, df], ignore_index=True)
