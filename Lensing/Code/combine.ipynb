# %%
import pandas as pd
import numpy as np

# %%
data_folder = '/Volumes/T7 Shield/Dump/Sim_3/individual_results'

data = pd.DataFrame()

for i in range(200):
    file_path = f'{data_folder}/results_rank_{i}.csv'
    try:
        # Attempt to read the CSV file
        df = pd.read_csv(file_path, header=0)
    except FileNotFoundError:
        # If the file does not exist, skip to the next iteration
        print(f"File {file_path} not found. Skipping.")
        continue
    print("Number of Models in file", i, ":", len(df))
    data = pd.concat([data, df], ignore_index=True)
# Out:
# Number of Models in file 0 : 5000
# Number of Models in file 1 : 5000
# Number of Models in file 2 : 5000
# Number of Models in file 3 : 5000
# Number of Models in file 4 : 5000
# Number of Models in file 5 : 5000
# Number of Models in file 6 : 5000
# Number of Models in file 7 : 5000
# Number of Models in file 8 : 5000
# Number of Models in file 9 : 5000
# Number of Models in file 10 : 5000
# Number of Models in file 11 : 5000
# Number of Models in file 12 : 5000
# Number of Models in file 13 : 5000
# Number of Models in file 14 : 5000
# Number of Models in file 15 : 5000
# Number of Models in file 16 : 5000
# Number of Models in file 17 : 5000
# Number of Models in file 18 : 5000
# Number of Models in file 19 : 5000
# Number of Models in file 20 : 5000
# Number of Models in file 21 : 5000
# Number of Models in file 22 : 5000
# Number of Models in file 23 : 5000
# Number of Models in file 24 : 5000
# Number of Models in file 25 : 5000
# Number of Models in file 26 : 5000
# Number of Models in file 27 : 5000
# Number of Models in file 28 : 5000
# Number of Models in file 29 : 5000
# Number of Models in file 30 : 5000
# Number of Models in file 31 : 5000
# Number of Models in file 32 : 5000
# Number of Models in file 33 : 5000
# Number of Models in file 34 : 5000
# Number of Models in file 35 : 5000
# Number of Models in file 36 : 5000
# Number of Models in file 37 : 5000
# Number of Models in file 38 : 5000
# Number of Models in file 39 : 5000
# Number of Models in file 40 : 5000
# Number of Models in file 41 : 5000
# Number of Models in file 42 : 5000
# Number of Models in file 43 : 5000
# Number of Models in file 44 : 5000
# Number of Models in file 45 : 5000
# Number of Models in file 46 : 5000
# Number of Models in file 47 : 5000
# Number of Models in file 48 : 5000
# Number of Models in file 49 : 5000
# Number of Models in file 50 : 5000
# Number of Models in file 51 : 5000
# Number of Models in file 52 : 5000
# Number of Models in file 53 : 5000
# Number of Models in file 54 : 5000
# Number of Models in file 55 : 5000
# Number of Models in file 56 : 5000
# Number of Models in file 57 : 5000
# Number of Models in file 58 : 5000
# Number of Models in file 59 : 5000
# Number of Models in file 60 : 5000
# Number of Models in file 61 : 5000
# Number of Models in file 62 : 5000
# Number of Models in file 63 : 5000
# Number of Models in file 64 : 5000
# Number of Models in file 65 : 5000
# Number of Models in file 66 : 5000
# Number of Models in file 67 : 5000
# Number of Models in file 68 : 5000
# Number of Models in file 69 : 5000
# Number of Models in file 70 : 5000
# Number of Models in file 71 : 5000
# Number of Models in file 72 : 5000
# Number of Models in file 73 : 5000
# Number of Models in file 74 : 5000
# Number of Models in file 75 : 5000
# Number of Models in file 76 : 5000
# Number of Models in file 77 : 5000
# Number of Models in file 78 : 5000
# Number of Models in file 79 : 5000
# Number of Models in file 80 : 5000
# Number of Models in file 81 : 5000
# Number of Models in file 82 : 5000
# Number of Models in file 83 : 5000
# Number of Models in file 84 : 5000
# Number of Models in file 85 : 5000
# Number of Models in file 86 : 5000
# Number of Models in file 87 : 5000
# Number of Models in file 88 : 5000
# Number of Models in file 89 : 5000
# Number of Models in file 90 : 5000
# Number of Models in file 91 : 5000
# Number of Models in file 92 : 5000
# Number of Models in file 93 : 5000
# Number of Models in file 94 : 5000
# Number of Models in file 95 : 5000
# Number of Models in file 96 : 5000
# Number of Models in file 97 : 5000
# Number of Models in file 98 : 5000
# Number of Models in file 99 : 5000
# Number of Models in file 100 : 5000
# Number of Models in file 101 : 5000
# Number of Models in file 102 : 5000
# Number of Models in file 103 : 5000
# Number of Models in file 104 : 5000
# Number of Models in file 105 : 5000
# Number of Models in file 106 : 5000
# Number of Models in file 107 : 5000
# Number of Models in file 108 : 5000
# Number of Models in file 109 : 5000
# Number of Models in file 110 : 5000
# Number of Models in file 111 : 5000
# Number of Models in file 112 : 5000
# Number of Models in file 113 : 5000
# Number of Models in file 114 : 5000
# Number of Models in file 115 : 5000
# Number of Models in file 116 : 5000
# Number of Models in file 117 : 5000
# Number of Models in file 118 : 5000
# Number of Models in file 119 : 5000
# Number of Models in file 120 : 5000
# Number of Models in file 121 : 5000
# Number of Models in file 122 : 5000
# Number of Models in file 123 : 5000
# Number of Models in file 124 : 5000
# Number of Models in file 125 : 5000
# Number of Models in file 126 : 5000
# Number of Models in file 127 : 5000
# Number of Models in file 128 : 5000
# Number of Models in file 129 : 5000
# Number of Models in file 130 : 5000
# Number of Models in file 131 : 5000
# Number of Models in file 132 : 5000
# Number of Models in file 133 : 5000
# Number of Models in file 134 : 5000
# Number of Models in file 135 : 5000
# Number of Models in file 136 : 5000
# Number of Models in file 137 : 5000
# Number of Models in file 138 : 5000
# Number of Models in file 139 : 5000
# Number of Models in file 140 : 5000
# Number of Models in file 141 : 5000
# Number of Models in file 142 : 5000
# Number of Models in file 143 : 5000
# Number of Models in file 144 : 5000
# Number of Models in file 145 : 5000
# Number of Models in file 146 : 5000
# Number of Models in file 147 : 5000
# Number of Models in file 148 : 5000
# Number of Models in file 149 : 5000
# Number of Models in file 150 : 5000
# Number of Models in file 151 : 5000
# Number of Models in file 152 : 5000
# Number of Models in file 153 : 5000
# Number of Models in file 154 : 5000
# Number of Models in file 155 : 5000
# Number of Models in file 156 : 5000
# Number of Models in file 157 : 5000
# Number of Models in file 158 : 5000
# Number of Models in file 159 : 5000
# Number of Models in file 160 : 5000
# Number of Models in file 161 : 5000
# Number of Models in file 162 : 5000
# Number of Models in file 163 : 5000
# Number of Models in file 164 : 5000
# Number of Models in file 165 : 5000
# Number of Models in file 166 : 5000
# Number of Models in file 167 : 5000
# Number of Models in file 168 : 5000
# Number of Models in file 169 : 5000
# Number of Models in file 170 : 5000
# Number of Models in file 171 : 5000
# Number of Models in file 172 : 5000
# Number of Models in file 173 : 5000
# Number of Models in file 174 : 5000
# Number of Models in file 175 : 5000
# Number of Models in file 176 : 5000
# Number of Models in file 177 : 5000
# Number of Models in file 178 : 5000
# Number of Models in file 179 : 5000
# Number of Models in file 180 : 5000
# Number of Models in file 181 : 5000
# Number of Models in file 182 : 5000
# Number of Models in file 183 : 5000
# Number of Models in file 184 : 5000
# Number of Models in file 185 : 5000
# Number of Models in file 186 : 5000
# Number of Models in file 187 : 5000
# Number of Models in file 188 : 5000
# Number of Models in file 189 : 5000
# Number of Models in file 190 : 5000
# Number of Models in file 191 : 5000
# Number of Models in file 192 : 5000
# Number of Models in file 193 : 5000
# Number of Models in file 194 : 5000
# Number of Models in file 195 : 5000
# Number of Models in file 196 : 5000
# Number of Models in file 197 : 5000
# Number of Models in file 198 : 5000
# Number of Models in file 199 : 5000

# %%
data
# Out:
#             m          n    o  num_images   pos_rms     mag_rms  avg_mag_per  \
# 0       0.001    0.00000  0.0           4  0.000000   25.751322   501.108266
# 1       0.001   72.07207  0.0           4  0.001196   26.107632   504.398530
# 2       0.001  144.14414  0.0           4  0.000000   21.355412   430.867693
# 3       0.001  216.21622  0.0           4  0.000000  176.742730  2823.107122
# 4       0.001  288.28829  0.0           4  0.001196   70.832711  1191.135789
# ...       ...        ...  ...         ...       ...         ...          ...
# 999995  0.100   71.71171  0.0           4  0.001196   17.409888   370.529020
# 999996  0.100  143.78378  0.0           4  0.000000    4.944159   179.262083
# 999997  0.100  215.85586  0.0           4  0.001257   80.200805  1336.513928
# 999998  0.100  287.92793  0.0           4  0.001196   22.271640   445.393263
# 999999  0.100  360.00000  0.0           4  0.000000   12.097242   290.447060
#
#             chi2  source_x  source_y  ...     POW_e  POW_$θ_{e}$  \
# 0       0.000002  1.081561  1.105082  ...  0.076947     59.39047
# 1       2.639973  1.081536  1.105069  ...  0.067329     55.26082
# 2       0.000003  1.081427  1.101334  ...  0.157557     57.04815
# 3       0.000001  1.080939  1.103055  ...  0.012420     78.57577
# 4       2.542626  1.081071  1.103191  ...  0.031092     55.18890
# ...          ...       ...       ...  ...       ...          ...
# 999995  2.690902  1.081823  1.106149  ...  0.092246     55.32237
# 999996  0.000003  1.083077  1.109023  ...  0.226898     57.18447
# 999997  2.350751  1.081040  1.104064  ...  0.000014     53.16622
# 999998  2.659887  1.081639  1.105469  ...  0.076241     55.28238
# 999999  0.000002  1.082133  1.107227  ...  0.127621     58.23498
#
#         POW_$r_{Ein}$  POW_$\gamma$ (PWI)  PERT_$z_{s,fid}$  PERT_x  PERT_y  \
# 0            0.474466            2.096378               1.0    1.06    1.06
# 1            0.474797            2.189677               1.0    1.06    1.06
# 2            0.475663            1.788276               1.0    1.06    1.06
# 3            0.474266            1.718696               1.0    1.06    1.06
# 4            0.474708            1.901594               1.0    1.06    1.06
# ...               ...                 ...               ...     ...     ...
# 999995       0.474876            2.296210               1.0    1.06    1.06
# 999996       0.475953            2.207913               1.0    1.06    1.06
# 999997       0.474639            2.299998               1.0    1.06    1.06
# 999998       0.474820            2.232606               1.0    1.06    1.06
# 999999       0.474695            2.263195               1.0    1.06    1.06
#
#         PERT_$\gamma$  PERT_$θ_{\gamma}$  PERT_$\kappa$
# 0        5.371272e-03          -8.876973            0.0
# 1        1.674995e-08          75.705220            0.0
# 2        3.495580e-02         148.974000            0.0
# 3        5.262961e-03         208.129300            0.0
# 4        2.443366e-09         292.599600            0.0
# ...               ...                ...            ...
# 999995   1.348371e-07          59.372460            0.0
# 999996   1.996739e-02         152.091900            0.0
# 999997   8.298165e-03         235.151800            0.0
# 999998   8.692244e-08         321.667900            0.0
# 999999   6.049995e-03         347.584500            0.0
#
# [1000000 rows x 43 columns]

# %%
data.to_csv('/Volumes/T7 Shield/Simulation Output/System 3/Sim 15.csv', index=False)

# %%
data_folder = '/Volumes/T7 Shield/Dump/Sim_4/progress_status'

progress = pd.DataFrame()

for i in range(100):
    file_path = f'{data_folder}/worker_{i}.status'
    try:
        df = pd.read_csv(file_path, header=None)
    except FileNotFoundError:
        print(f"File {file_path} not found. Skipping.")
        continue
    progress = pd.concat([progress, df], ignore_index=True)

# %%
progress
# Out:
#         0
# 0   10000
# 1   10000
# 2   10000
# 3   10000
# 4   10000
# ..    ...
# 95  10000
# 96  10000
# 97  10000
# 98  10000
# 99  10000
#
# [100 rows x 1 columns]
